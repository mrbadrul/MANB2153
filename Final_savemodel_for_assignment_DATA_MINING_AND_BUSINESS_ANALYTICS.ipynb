# %% [markdown]
# <a href="https://colab.research.google.com/github/mrbadrul/MANB2153/blob/master/Final_savemodel_for_assignment_DATA_MINING_AND_BUSINESS_ANALYTICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 3 - Visualization
#
# Group 6 - VulcanMed Medical Services
# 1. BADRUL HISYAM BIN AZHAR (MAN 181026)
# 2. FELICIA YEW HUI SHYAN (MAN 181008)

# %% [markdown]
# Dataset description
#
# The dataset compiled in this study collected from Kaggle website, (https://www.kaggle.com/uciml/pima-indians-diabetes-database)  which originally taken from the National Institute of Diabetes and Digestive and Kidney Diseases.
#
# The dataset consists set of Pima Female Indians who are at least 21 years with several medical diagnostic measurements and prediction whether the patient has diabetes or not.
# The dataset involves 768 women with 8 characteristics and 1 target (class label).
# The features (columns) are:
#
# * Number of times pregnant.
# * Plasma glucose concentration.
# * Diastolic blood presure in mm.
# * Triceps skin fold thickness in mm.
# * 2-hour serun insulin in mu U/ml.
# * Body mass index.
# * Diabetes pedigree function.
# * Age in years.

# %%
###first upload dataset from https://www.kaggle.com/uciml/pima-indians-diabetes-database/downloads/pima-indians-diabetes-database.zip/1 into colab
##dataset before cleaning and transformation
import os
import pandas as pd
import numpy as np
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
print(df.shape)
df.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(df.groupby('Outcome').size())
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Observations
#
# * There are some columns that have minimum value of zero which is irrelevant to the features.
# * It indicates invalid or missing values that are marked as 0.
# * The columns which have the irrelevant zero minimum value: plasma glucose concentration, diastolic blood pressure, triceps skinfold thickness, 2-hour serum insulin, body mass index.
# * The outcome represents positive (1) or negative (0) for diabetes.
# * All features are numerical values.

# %%
print(df.groupby('Outcome').size())
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# Visualization of Data before identify and mark values as values
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
# Visualizing Outlier

#Comparing distributions, the centre, spread and overall range  w.r.t Outcome
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(16,16))

df.boxplot(column='Pregnancies', by='Outcome',ax=axes[0,0])
df.boxplot(column='Glucose', by='Outcome', ax=axes[0,1])
df.boxplot(column='BloodPressure', by='Outcome',ax=axes[1,0])
df.boxplot(column='SkinThickness', by='Outcome', ax=axes[1,1])
df.boxplot(column='Insulin', by='Outcome',ax=axes[2,0])
df.boxplot(column='BMI', by='Outcome', ax=axes[2,1])
df.boxplot(column='DiabetesPedigreeFunction', by='Outcome',ax=axes[3,0])
df.boxplot(column='Age', by='Outcome', ax=axes[3,1])

fig.tight_layout()

# %%
#Analyze Outliers
print("Total : ", df[df.BloodPressure == 0].shape[0])
print(df[df.BloodPressure == 0].groupby('Outcome')['Age'].count())
# Out:
# Total :  35
# Outcome
# 0    19
# 1    16
# Name: Age, dtype: int64

# %%
print("Total : ", df[df.Glucose == 0].shape[0])
print(df[df.Glucose == 0].groupby('Outcome')['Age'].count())
# Out:
# Total :  5
# Outcome
# 0    3
# 1    2
# Name: Age, dtype: int64

# %%
print("Total : ", df[df.SkinThickness == 0].shape[0])
print(df[df.SkinThickness == 0].groupby('Outcome')['Age'].count())
# Out:
# Total :  227
# Outcome
# 0    139
# 1     88
# Name: Age, dtype: int64

# %%
print("Total : ", df[df.BMI == 0].shape[0])
print(df[df.BMI == 0].groupby('Outcome')['Age'].count())
# Out:
# Total :  11
# Outcome
# 0    9
# 1    2
# Name: Age, dtype: int64

# %%
print("Total : ", df[df.Insulin == 0].shape[0])
print(df[df.Insulin == 0].groupby('Outcome')['Age'].count())
# Out:
# Total :  374
# Outcome
# 0    236
# 1    138
# Name: Age, dtype: int64

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print((df[['Glucose', 'BloodPressure', 'SkinThickness','Insulin', 'BMI']] == 0).sum())
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
# Median value for Glucose
median_glucose = df['Glucose'].median()
# Substitute in the Glucose where values are 0
df['Glucose'] = df['Glucose'].replace(
    to_replace=0, value=median_glucose)

# Median value for BloodPressure
median_bloodpressure = df['BloodPressure'].median()
# Substitute in the BloodP where values are 0
df['BloodPressure'] = df['BloodPressure'].replace(
    to_replace=0, value=median_bloodpressure)

# Median value for SkinThickness
median_skinthickness = df['SkinThickness'].median()
# Substitute in the SkinThickness where values are 0
df['SkinThickness'] = df['SkinThickness'].replace(
    to_replace=0, value=median_skinthickness)

# Median value for Insulin
median_insulin = df['Insulin'].median()
# Substitute in the Insulin where values are 0
df['Insulin'] = df['Insulin'].replace(
    to_replace=0, value=median_insulin)

# Median value for BMI
median_bmi = df['BMI'].median()
# Substitute in the BMI where the values are 0
df['BMI'] = df['BMI'].replace(
    to_replace=0, value=median_bmi)

# %%
#exclude
# mark zero values as missing or NaN
#df[['Glucose', 'BloodPressure', 'SkinThickness','Insulin', 'BMI']] = df[['Glucose', 'BloodPressure', 'SkinThickness','Insulin', 'BMI']].replace(0, np.NaN)

# %%
#exclude
# count the number of NaN values in each column
#print(df.isnull().sum())

# %%
#exclude
# print the first 20 rows of data
#df.head(20)

# %%
#exclude
# fill missing values with median column values
#df.fillna(df.median(), inplace=True)

#exclude
# count the number of NaN values in each column
#print(df.isnull().sum())

# %%
# print the first 10 rows of data
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
# 2            8      183             64             23     30.5  23.3
# 3            1       89             66             23     94.0  28.1
# 4            0      137             40             35    168.0  43.1
# 5            5      116             74             23     30.5  25.6
# 6            3       78             50             32     88.0  31.0
# 7           10      115             72             23     30.5  35.3
# 8            2      197             70             45    543.0  30.5
# 9            8      125             96             23     30.5  32.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      27.334635   94.652344
# std       3.369578   30.438286      12.096642       9.229014  105.547598
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      23.000000   30.500000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450911                  0.471876   33.240885    0.348958
# std      6.875366                  0.331329   11.760232    0.476951
# ...

# %%
import seaborn as sns

sns.countplot(df['Outcome'],label="Count")

# %%
import matplotlib.pyplot as plt

# Histogram
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
#feature-class relationships
# Histogram Matrix
df.groupby('Outcome').hist(figsize=(10, 10))
# Out:
# Outcome
# 0    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object

# %%
print(df.groupby('Outcome').size())

sns.countplot(df['Outcome'],label="Count")
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# Visualizing Outlier


# Comparing distributions, the centre, spread and overall range  w.r.t Outcome
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(16,16))

df.boxplot(column='Pregnancies', by='Outcome',ax=axes[0,0])
df.boxplot(column='Glucose', by='Outcome', ax=axes[0,1])
df.boxplot(column='BloodPressure', by='Outcome',ax=axes[1,0])
df.boxplot(column='SkinThickness', by='Outcome', ax=axes[1,1])
df.boxplot(column='Insulin', by='Outcome',ax=axes[2,0])
df.boxplot(column='BMI', by='Outcome', ax=axes[2,1])
df.boxplot(column='DiabetesPedigreeFunction', by='Outcome',ax=axes[3,0])
df.boxplot(column='Age', by='Outcome', ax=axes[3,1])

fig.tight_layout()

# %%
# Correlation
corr = df.corr()
# %matplotlib inline
import seaborn as sns
sns.heatmap(corr, annot = True)
plt.show()

# %%
# Scatter Matrix (Feature feature relationship)
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f38f1aceb38>,
# ...
#       dtype=object)

# %%
# Visualize Pair Plot
sns.pairplot(df)
plt.show()

# %%
# Split training/testing dataset: 80% / 20%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(
    df, test_size=0.2, random_state=42)

# Separate labels from the rest of the dataset
train_set_labels = train_set["Outcome"].copy()
train_set = train_set.drop("Outcome", axis=1)

test_set_labels = test_set["Outcome"].copy()
test_set = test_set.drop("Outcome", axis=1)

# %%
##Nominalize the data
from sklearn.preprocessing import MinMaxScaler as Scaler

scaler = Scaler()
scaler.fit(train_set)
train_set_scaled = scaler.transform(train_set)
test_set_scaled = scaler.transform(test_set)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
df = pd.DataFrame(data=train_set_scaled)
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.117647  0.258065  0.489796  0.272727  0.019832  0.282209  0.096499
# 1  0.529412  0.438710  0.591837  0.290909  0.019832  0.204499  0.514091
# 2  0.058824  0.612903  0.224490  0.200000  0.082933  0.214724  0.245944
# 3  0.000000  0.754839  0.265306  0.272727  0.019832  0.075665  0.075149
# 4  0.352941  0.580645  0.571429  0.527273  0.427885  0.572597  0.068318
#
#           7
# 0  0.000000
# 1  0.483333
# 2  0.016667
# 3  0.733333
# 4  0.416667

# %%
# to select the best algortihm
# result select SVC @ LSVC algorithm
#this will answer the question why we choose this model

from sklearn import model_selection
# Import all algorithms to test
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor

models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVC', SVC()))
models.append(('LSVC', LinearSVC()))
models.append(('RFC', RandomForestClassifier()))
models.append(('DTR', DecisionTreeRegressor()))

seed = 7
results = []
names = []
X = train_set_scaled
Y = train_set_labels

# Test all the algorithm
for name, model in models:
    kfold = model_selection.KFold(
        n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(
        model, X, Y, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (
        name, cv_results.mean(), cv_results.std())
    print(msg)
    
    
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
#find the best parameter for algorithm 

from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [1.0, 10.0, 50.0],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'shrinking': [True, False],
    'gamma': ['auto', 1, 0.1],
    'coef0': [0.0, 0.1, 0.5]
}

model_svc = SVC()

grid_search = GridSearchCV(
    model_svc, param_grid, cv=10, scoring='accuracy')
grid_search.fit(train_set_scaled, train_set_labels)

# Print the best score found
grid_search.best_score_
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 0.7687296416938111

# %%
svc = grid_search.best_estimator_

# %%
X = train_set_scaled
Y = train_set_labels

# Train the model
svc.fit(X, Y)
# Out:
# SVC(C=10.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
##testing
y_pred = svc.predict(test_set_scaled)
y_true=test_set_labels

# %%
##mse
from sklearn.metrics import mean_squared_error
result_mse = mean_squared_error(y_true,y_pred)
print('MSE: ', +result_mse)

##accuracy
from sklearn.metrics import accuracy_score
result_acc = accuracy_score (y_true,y_pred)
print('Accuracy: ', + result_acc)

##confusion matrix
from sklearn.metrics import confusion_matrix
result_confmatrix = confusion_matrix(y_true,y_pred)
print('Confusion Matrix : ', +result_confmatrix)
# Out:
# MSE:  0.22727272727272727
# Accuracy:  0.7727272727272727
# Confusion Matrix :  [[83 16]
#  [19 36]]

# %%
# save model
from sklearn.externals import joblib
joblib.dump(svc, 'model_diabetes_svc.pkl')
# Out:
# ['model_diabetes_svc.pkl']
